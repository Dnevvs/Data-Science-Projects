# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span><ul class="toc-item"><li><span><a href="#Цель-проекта" data-toc-modified-id="Цель-проекта-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Цель проекта</a></span></li><li><span><a href="#Постановка-задачи" data-toc-modified-id="Постановка-задачи-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Постановка задачи</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Описание данных</a></span></li></ul></li><li><span><a href="#Загрузка-необходимых-библиотек-и-функций" data-toc-modified-id="Загрузка-необходимых-библиотек-и-функций-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Загрузка необходимых библиотек и функций</a></span></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Загрузка данных</a></span><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Подготовка данных</a></span></li></ul></li><li><span><a href="#Изучение-данных" data-toc-modified-id="Изучение-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Изучение данных</a></span><ul class="toc-item"><li><span><a href="#Формирование-и-изучение-отчета-о-данных" data-toc-modified-id="Формирование-и-изучение-отчета-о-данных-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Формирование и изучение отчета о данных</a></span></li><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Подготовка-необходимых-данных" data-toc-modified-id="Подготовка-необходимых-данных-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Подготовка необходимых данных</a></span></li><li><span><a href="#Временной-промежуток-исследования" data-toc-modified-id="Временной-промежуток-исследования-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Временной промежуток исследования</a></span></li><li><span><a href="#Статистический-анализ-признаков" data-toc-modified-id="Статистический-анализ-признаков-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Статистический анализ признаков</a></span></li><li><span><a href="#Графики-временного-ряда" data-toc-modified-id="Графики-временного-ряда-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Графики временного ряда</a></span></li><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Создание-признаков" data-toc-modified-id="Создание-признаков-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Создание признаков</a></span></li><li><span><a href="#Деление-на-выборки" data-toc-modified-id="Деление-на-выборки-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Деление на выборки</a></span></li><li><span><a href="#Тестирование-моделей" data-toc-modified-id="Тестирование-моделей-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Тестирование моделей</a></span><ul class="toc-item"><li><span><a href="#Линейная-регрессия-LinearRegression" data-toc-modified-id="Линейная-регрессия-LinearRegression-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Линейная регрессия <code>LinearRegression</code></a></span></li><li><span><a href="#Дерево-решений-DecisionTreeRegressor" data-toc-modified-id="Дерево-решений-DecisionTreeRegressor-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>Дерево решений <code>DecisionTreeRegressor</code></a></span></li><li><span><a href="#Градиентный-бустинг-LGBMRegressor" data-toc-modified-id="Градиентный-бустинг-LGBMRegressor-6.3.3"><span class="toc-item-num">6.3.3&nbsp;&nbsp;</span>Градиентный бустинг <code>LGBMRegressor</code></a></span></li><li><span><a href="#Градиентный-бустинг-CatBoostRegressor" data-toc-modified-id="Градиентный-бустинг-CatBoostRegressor-6.3.4"><span class="toc-item-num">6.3.4&nbsp;&nbsp;</span>Градиентный бустинг <code>CatBoostRegressor</code></a></span></li></ul></li><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li><li><span><a href="#Анализ-моделей" data-toc-modified-id="Анализ-моделей-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Анализ моделей</a></span><ul class="toc-item"><li><span><a href="#Сравнение-моделей" data-toc-modified-id="Сравнение-моделей-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Сравнение моделей</a></span></li><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Тестирование</a></span><ul class="toc-item"><li><span><a href="#Проверка-лучшей-модели-на-тестовых-данных" data-toc-modified-id="Проверка-лучшей-модели-на-тестовых-данных-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Проверка лучшей модели на тестовых данных</a></span></li><li><span><a href="#Сравнение-предсказаний-с-реальными-значениями" data-toc-modified-id="Сравнение-предсказаний-с-реальными-значениями-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Сравнение предсказаний с реальными значениями</a></span></li></ul></li><li><span><a href="#Итоговые-выводы" data-toc-modified-id="Итоговые-выводы-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Итоговые выводы</a></span><ul class="toc-item"><li><span><a href="#Отчет-о-проделанной-работе" data-toc-modified-id="Отчет-о-проделанной-работе-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Отчет о проделанной работе</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# ### Цель проекта

# %% [markdown]
# Цель данного проекта - построить модель для предсказания количество заказов такси на следующий час.

# %% [markdown]
# ### Постановка задачи

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час - построить модель для такого предсказания.
#
# Значение метрики `RMSE` на тестовой выборке должно быть не больше 48.
#
# Необходимо:
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.

# %% [markdown]
# ### Описание данных

# %% [markdown]
# Данные находятся в файле `taxi.csv`.
#
# Признаки:
# * `datetime` - дата и время,
# * `num_orders`- количество заказов.

# %% [markdown]
# ##  Загрузка необходимых библиотек и функций

# %%
! pip install catboost -q
! pip install lightgbm -q
! pip install matplotlib==3.4.2 -q
! pip install missingno -q
! pip install numba==0.57.1 -q
! pip install numpy==1.23 -q
! pip install pandas==2.0.3 -q
! pip install -U scikit-learn -q
! pip install seaborn==0.12.2 -q;

# %%
import os
import time
import warnings
from itertools import product

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import (GridSearchCV, TimeSeriesSplit,
                                     cross_val_score, train_test_split)
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (FunctionTransformer, RobustScaler,
                                   StandardScaler)
from sklearn.tree import DecisionTreeRegressor
from statsmodels.tsa.seasonal import seasonal_decompose

import missingno as msno

warnings.filterwarnings("ignore");

# %%
RANDOM_STATE = 42
TSS_CV = TimeSeriesSplit(n_splits=5);

# %%
def df_research_method(df, method):
    """
    Применяет определенный метод изучения данных в датасете.

    Параметры:
    - df: Исследуемый датасет.
    - method: Название метода.
   
    Пример:
    ```
    df_research_method(df, 'head')
    ```
    """
    
    if method == 'head':
        display(df.head())
    elif method == 'shape':
        display(df.shape)
    elif method == 'describe':
        display(df.describe().T)
    elif method == 'duplicated':
        dp = df.duplicated().sum()
        display(dp)
        if dp > 0:
            print('Количество явных дубликатов:')
            display(df[df.duplicated()])
    elif method == 'unique':
        for column in df.select_dtypes(include='object').columns:
            print(f'Уникальные значения в колонке {column}: {df[column].sort_values().unique()}')
    elif method == 'msno':
        display(msno.bar(df))
        plt.show()
    else:
        display(df.info())

# Функция применения методов к списку датасетов
def df_research(df_list, df_methods):
    """
    Применяет метод из списка для изучения данных в списке датасетов.

    Параметры:
    - df_list: Список исследуемых датасетов (имя переменной, описание, имя файла).
    - df_method: Список названий методов.
   
    Пример:
    ```
    df_research(df_list, df_methods)
    ```
    """
    
    for method in df_methods:
        print(f'Изучим {method[1]}:')
        print('-' * 70)
        for df in df_list:
            globals()[df[0]] = globals()[df[0]].applymap(lambda x: x.lower() if isinstance(x, str) else x)
            print('Dataset:', df[1])
            print('-' * 70)
            df_research_method(globals()[df[0]], method[0])
            print('-' * 70);

# %%
# Функция для отображения количественного признака    
def show_numeric_feature(df, column, title, x_label, y_label):
    """
    Отображает гистограмму и "ящик с усами" для количественного признака.

    Параметры:
    - df: Датасет.
    - column: Название колонки признака.
    - title: Заголовок диаграммы.
    - x_label: Название оси X.
    - y_label: Название оси Y.
   
    Пример:
    ```
    show_numeric_feature(market_file_df, 
                         'выручка',
                         'Выручка за период',
                         'Выручка',
                         'Количество покупателей')
    ```
    """
    
    fig, axes = plt.subplots(1, 2, figsize=(18, 6))
    plt.suptitle(title.upper(), fontsize=16, ha='center')
    sns.histplot(data=df[column], color='g', kde=False, ax=axes[0], bins=30) 
    axes[0].set_xlabel(x_label)
    axes[0].set_ylabel(y_label)
    sns.boxplot(x=df[column], color='c')
    axes[1].set_xlabel(y_label)
    plt.show()
    print('Описание признака:', x_label)
    display(df[column].describe().T)
    
    
# Функция для отображения количественного признака по списку
def show_numeric_feature_by_list(df, features):
    """
    Отображает гистограмму и "ящик с усами" для количественного признака
    по списку.

    Параметры:
    - df: Датасет.
    - features: Список признаков для отображения.
   
    Пример:
    ```
    show_numeric_feature_by_list(market_file_df, 
        market_file_numeric_features)
    ```
    """
    
    for feature in features:
        title = feature[2]
        column = feature[0]
        x_label = feature[1]
        y_label = 'Количество'
        show_numeric_feature(df, column, title, x_label, y_label);

# %%
def show_barplot(title, x, y, x_label, y_label):
    plt.figure(figsize=(12, 6))
    ax = sns.barplot(x=x, y=y)
    plt.suptitle(title, fontsize=16, ha='center')
    ax.figsize=(16, 6) 
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.bar_label(ax.containers[0],
             color='black',
             fontsize=12,
             fontweight='bold')
    plt.show();

# %%
def make_features(data_input, max_lag, rolling_mean_size):
    """
    Добавляет новые признаки к DataFrame для анализа временных данных.

    Параметры:
    - data_input: Исходный DataFrame, содержащий временные данные.
    - max_lag: Максимальная задержка (lag) для создания отстающих признаков.
    - rolling_mean_size: Размер окна скользящего среднего для создания признака скользящего среднего.

    Результат:
    - Исходный DataFrame с добавленными признаками:
        - 'month': Месяц из индекса.
        - 'day': День месяца из индекса.
        - 'hour': Час из индекса.
        - 'dayofweek': День недели из индекса.
        - 'lag_{lag}': Отстающий признак для количества заказов с задержкой в {lag} временных единиц.
        - 'rolling_mean': Скользящее среднее для количества заказов.

    Пример вызова:
    ```
    make_features(data, 7, 1)
    ```

    """
    data = data_input.copy()
    data['day'] = data.index.day
    data['hour'] = data.index.hour
    data['dayofweek'] = data.index.dayofweek
    
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data['num_orders'].shift(lag)

    data['rolling_mean'] = data['num_orders'].shift().rolling(rolling_mean_size).mean()
    return data;

# %% [markdown]
# ## Загрузка данных

# %%
# Список датасетов для загрузки - 
# имя переменной датасета, описание датасета, имя файла
datasets = [
    ['taxi', 'Данные о заказах такси', 'taxi.csv', ['datetime']]
]

# Пути для загрузки
dir_1 = '/datasets/'
dir_2 = 'https://code.s3.yandex.net/datasets/';

# %%
# Проведем загрузку
for df in datasets:
    path_1 = f'{dir_1}{df[2]}'
    path_2 = f'{dir_2}{df[2]}'
    if os.path.exists(path_1):
        globals()[df[0]] = pd.read_csv(path_1, sep=',', decimal='.', index_col=df[3], parse_dates=df[3])
    elif os.path.exists(pth2):
        globals()[df[0]] = pd.read_csv(path_2, sep=',', decimal='.', index_col=df[3], parse_dates=df[3])
    else:
        print(f'Ошибка загрузки датасета "{df[1]}"')
        break
    print(f'Датасет "{df[1]}" загружен 100%');
# Out:
# Датасет "Данные о заказах такси" загружен 100%

# %% [markdown]
# ### Подготовка данных

# %% [markdown]
# Проведем ресемплирование данных по 1 часу:

# %%
taxi = taxi.sort_index()
taxi = taxi.resample('1H').sum() 
# Проверим результат
display(taxi.head())
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00         124
# 2018-03-01 01:00:00          85
# 2018-03-01 02:00:00          71
# 2018-03-01 03:00:00          66
# 2018-03-01 04:00:00          43

# %% [markdown]
# ## Изучение данных

# %% [markdown]
# ### Формирование и изучение отчета о данных

# %% [markdown]
# Подготовим спискок методов изучения данных:

# %%
df_methods = [['info', 'общую информацию о датасете'],
              ['shape', 'размеры датасета'],
              ['describe', 'описание полей датасета'],
              ['msno', 'пропуски']
             ];

# %% [markdown]
# Изучим данные:

# %%
df_research(datasets, df_methods);
# Out:
# Изучим общую информацию о датасете:
# ----------------------------------------------------------------------
# Dataset: Данные о заказах такси
# ----------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4416 entries, 2018-03-01 00:00:00 to 2018-08-31 23:00:00
# Freq: H
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  4416 non-null   int64
# dtypes: int64(1)
# memory usage: 69.0 KB
# None
# ----------------------------------------------------------------------
# Изучим размеры датасета:
# ----------------------------------------------------------------------
# Dataset: Данные о заказах такси
# ----------------------------------------------------------------------
# (4416, 1)
# ----------------------------------------------------------------------
# Изучим описание полей датасета:
# ...

# %% [markdown]
# ### Промежуточные выводы

# %% [markdown]
# Проведена загрузка и ресемплирование данных по 1 часу.
#
# В ходе изучения данных выявили, что:
# - Пропуски в данных не выявлены.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Подготовка необходимых данных

# %%
# Списки признаков для анализа
# в формате - признак, название, комментарий
# Подробный список количественных призаков
df_numeric_features = [
    ['num_orders', 'Кол-во заказов', 'количество заказов такси']
]

# Список числовых признаков
df_num_columns = ['num_orders'];

# %% [markdown]
# ### Временной промежуток исследования

# %%
print("Начало:", taxi.index.min())
print("Окончание:", taxi.index.max());
# Out:
# Начало: 2018-03-01 00:00:00
# Окончание: 2018-08-31 23:00:00

# %% [markdown]
# ### Статистический анализ признаков

# %%
# Анализ количественных признаков
for df in datasets:
    print('Dataset:', df[1])
    show_numeric_feature_by_list(globals()[df[0]], df_numeric_features);
# Out:
# Dataset: Данные о заказах такси
# Описание признака: Кол-во заказов
# count    4416.000000
# mean       84.422781
# std        45.023853
# min         0.000000
# 25%        54.000000
# 50%        78.000000
# 75%       107.000000
# max       462.000000
# Name: num_orders, dtype: float64

# %% [markdown]
# **После анализа количественных признаков мы можем сделать следующие выводы:**
# * `Количество заказов` варьируются от 0 до 462 заказов в час, с медианным значением 78. Распределение смещено влево.

# %% [markdown]
# ### Графики временного ряда

# %% [markdown]
# Разложим временной ряд на тренд и сезонную компоненту:

# %%
decomposed = seasonal_decompose(taxi) 
plt.figure(figsize=(16, 12))
plt.subplot(311)
decomposed.trend.plot(ax=plt.gca())
plt.title('Тренд')
plt.xlabel('Период')
plt.ylabel('Количество заказов')
plt.grid(True)
plt.subplot(312)
decomposed.seasonal.plot(ax=plt.gca()) 
plt.title('Сезонность')
plt.xlabel('Период')
plt.ylabel('Количество заказов')
plt.grid(True)
plt.subplot(313)
decomposed.resid.plot(ax=plt.gca()) 
plt.title('Остатки')
plt.xlabel('Период')
plt.ylabel('Количество заказов')
plt.grid(True)
plt.tight_layout()

# %% [markdown]
# На графиках можно наблюдать, что линия тренда растет и достигает пика в конце августа. Вероятно это связано с окончанием сезона отпусков.

# %% [markdown]
# На графике сезонности нельзя увидеть все закономерности, так как есть данные только за 6 месяцев.
# Тем не менее, можно отметить, что основные колебания происходят в течение каждого дня.
#
# Изучим информацию в течение дня более подробно.Для анализа выберем середину временного интервала - 01.06.2018:

# %%
plt.figure(figsize=(16, 6))
decomposed.seasonal['2018-06-01':'2018-06-02 00:00:00'].plot(ax=plt.gca())
plt.xlabel('Часы')
plt.title('Сезонность зв 01.06.2018')
plt.ylabel('Количество заказов')
plt.grid(True)

# %% [markdown]
# На графике заметно, что пик заказов такси приходится на ночное время - примерно с 23:00 до 02:00, существенный спад наблюдается в 6 утра. В ночные часы вероятно не работает общественный транспорт. С 6 утра скорее всего он начинает работать и пока на нем невысокая загрузка, поэтому падает спрос на такси.

# %% [markdown]
# Построим график распределения заказов по времени:

# %%
taxi['mean'] = taxi['num_orders'].rolling(72).mean()
taxi['std'] = taxi['num_orders'].rolling(72).std()
plt.figure(figsize=(16, 8)) 
plt.plot(taxi)
plt.grid(True)
plt.title(datasets[0][1].upper())
plt.xlabel('Период')
plt.ylabel('Количество заказов')
plt.legend(('num_orders', 'mean', 'std'))
taxi = taxi.drop(['mean', 'std'], axis = 1);

# %% [markdown]
# По графику заметно, что это скорее нестационарный временной ряд, так как со временем меняются среднее и стандартное отклонение.
#
# Наблюдается рост среднего и стандартного отклонения.

# %% [markdown]
# ### Промежуточные выводы

# %% [markdown]
# * Наблюдения проводились с 1 марта по 31 августа 2018 года.*
# * Минимальное количество заказов такси в час составляло 0, максимальное - 462, медианное - 78.
# * На графиках можно наблюдать, что линия тренда растет и достигает пика в конце августа. Вероятно это связано с окончанием сезона отпусков.
# * На графике сезонности нельзя увидеть все закономерности, так как есть данные только за 6 месяцев. Тем не менее, можно отметить, что основные колебания происходят в течение каждого дня.
# * На однодневном графике заметно, что пик заказов такси приходится на ночное время - примерно с 23:00 до 02:00, существенный спад наблюдается в 6 утра. В ночные часы вероятно не работает общественный транспорт. С 6 утра скорее всего он начинает работать и пока на нем невысокая загрузка, поэтому падает спрос на такси.
# * По графику распределения заказов заметно, что это скорее нестационарный временной ряд, так как со временем меняются среднее и стандартное отклонение. Наблюдается рост среднего и стандартного отклонения.

# %% [markdown]
# ## Обучение моделей

# %% [markdown]
# ### Создание признаков

# %%
# Создадим признаки c лагом - 1 неделя и размером окна - 1 день
taxi_new = make_features(taxi, 168, 24)
# Проверим рехзультат
display(taxi_new.head());
# Out:
#                      num_orders  day  hour  dayofweek  lag_1  lag_2  lag_3  \
# datetime
# 2018-03-01 00:00:00         124    1     0          3    NaN    NaN    NaN
# 2018-03-01 01:00:00          85    1     1          3  124.0    NaN    NaN
# 2018-03-01 02:00:00          71    1     2          3   85.0  124.0    NaN
# 2018-03-01 03:00:00          66    1     3          3   71.0   85.0  124.0
# 2018-03-01 04:00:00          43    1     4          3   66.0   71.0   85.0
#
#                      lag_4  lag_5  lag_6  ...  lag_160  lag_161  lag_162  \
# datetime                                  ...
# 2018-03-01 00:00:00    NaN    NaN    NaN  ...      NaN      NaN      NaN
# 2018-03-01 01:00:00    NaN    NaN    NaN  ...      NaN      NaN      NaN
# 2018-03-01 02:00:00    NaN    NaN    NaN  ...      NaN      NaN      NaN
# 2018-03-01 03:00:00    NaN    NaN    NaN  ...      NaN      NaN      NaN
# 2018-03-01 04:00:00  124.0    NaN    NaN  ...      NaN      NaN      NaN
#
# ...

# %% [markdown]
# ### Деление на выборки

# %%
train, test = train_test_split(taxi_new, shuffle=False, test_size=0.1)
train = train.dropna()

features_train = train.drop('num_orders', axis = 1)
target_train = train['num_orders']
features_test = test.drop('num_orders', axis = 1)
target_test = test['num_orders'];

# %%
# Подготовка функции создания моделей
def create_model(pipeline, param_grid, features_train, target_train):
    result = {}
    # Создание модели
    grid_search = GridSearchCV(pipeline, param_grid, cv=TSS_CV, scoring='neg_root_mean_squared_error')
    # Обучение модели
    start_time = time.time()
    grid_search.fit(features_train, target_train)
    result['training_time'] = round(time.time() - start_time, 2)
    # Сохраненение модели с лучшими результами
    result['best_model'] = grid_search.best_estimator_
    # Формирование предсказаний
    start_time = time.time()
    result['predictions'] = result['best_model'].predict(features_test)
    result['prediction_time'] = round(time.time() - start_time, 2)
    # Сохранение лучшей метрики
    result['rmse'] = round(grid_search.best_score_ * -1, 5)
    result['grid_search'] = grid_search
    return result

# Список моделей для тестирования
models = {
    'LinearRegression': {},
    'DecisionTreeRegressor': {},
    'LGBMRegressor': {},
    'CatBoostRegressor': {}
};

# %% [markdown]
# ### Тестирование моделей

# %% [markdown]
# #### Линейная регрессия `LinearRegression`

# %%
# %%time
model_name = 'LinearRegression'
model = LinearRegression()
pipeline = Pipeline([
    ('scaler', StandardScaler(with_mean=False)),
    ('regressor', model) 
])
param_grid = {
    'scaler': [StandardScaler(with_mean=False), RobustScaler(with_centering=False), None]
}
models[model_name] = create_model(pipeline, param_grid, features_train, target_train)
print(f'Модель {model_name}')
print('-' * 70)
print(f'Время обучения: {models[model_name]["training_time"]} сек.')
print(f'Время предсказания: {models[model_name]["prediction_time"]} сек.')
print(f'RMSE: {models[model_name]["rmse"]}')
# print(f'Лучшая модель:{models[model_name]["best_model"]}')
print('-' * 70);
# Out:
# Модель LinearRegression
# ----------------------------------------------------------------------
# Время обучения: 6.54 сек.
# Время предсказания: 0.0 сек.
# RMSE: 22.54985
# ----------------------------------------------------------------------
# CPU times: user 3.59 s, sys: 2.98 s, total: 6.57 s
# Wall time: 6.55 s

# %% [markdown]
# #### Дерево решений `DecisionTreeRegressor`

# %%
# %%time
model_name = 'DecisionTreeRegressor'
model = DecisionTreeRegressor(random_state=RANDOM_STATE)
pipeline = Pipeline([
    ('scaler', StandardScaler(with_mean=False)),
    ('regressor', model) 
])
param_grid = {
    'scaler': [StandardScaler(with_mean=False), RobustScaler(with_centering=False), None],
    'regressor__max_depth': [5, 10, 15]
}
models[model_name] = create_model(pipeline, param_grid, features_train, target_train)
print(f'Модель {model_name}')
print('-' * 70)
print(f'Время обучения: {models[model_name]["training_time"]} сек.')
print(f'Время предсказания: {models[model_name]["prediction_time"]} сек.')
print(f'RMSE: {models[model_name]["rmse"]}')
# print(f'Лучшая модель:{models[model_name]["best_model"]}')
print('-' * 70);
# Out:
# Модель DecisionTreeRegressor
# ----------------------------------------------------------------------
# Время обучения: 10.12 сек.
# Время предсказания: 0.0 сек.
# RMSE: 27.64537
# ----------------------------------------------------------------------
# CPU times: user 10.1 s, sys: 0 ns, total: 10.1 s
# Wall time: 10.1 s

# %% [markdown]
# #### Градиентный бустинг `LGBMRegressor`

# %%
# %%time
model_name = 'LGBMRegressor'
model = LGBMRegressor(random_state=RANDOM_STATE)
pipeline = Pipeline([
    ('scaler', StandardScaler(with_mean=False)),
    ('regressor', model)
])
param_grid = {
    'scaler': [StandardScaler(with_mean=False), None],
    'regressor__num_leaves': [50, 100] 
}
models[model_name] = create_model(pipeline, param_grid, features_train, target_train)
print(f'Модель {model_name}')
print('-' * 70)
print(f'Время обучения: {models[model_name]["training_time"]} сек.')
print(f'Время предсказания: {models[model_name]["prediction_time"]} сек.')
print(f'RMSE: {models[model_name]["rmse"]}')
# print(f'Лучшая модель:{models[model_name]["best_model"]}')
print('-' * 70);
# Out:
# Модель LGBMRegressor
# ----------------------------------------------------------------------
# Время обучения: 522.77 сек.
# Время предсказания: 0.08 сек.
# RMSE: 23.12004
# ----------------------------------------------------------------------
# CPU times: user 8min 34s, sys: 2.65 s, total: 8min 36s
# Wall time: 8min 42s

# %% [markdown]
# #### Градиентный бустинг `CatBoostRegressor`

# %%
# %%time
model_name = 'CatBoostRegressor'
model = CatBoostRegressor(random_state=RANDOM_STATE, verbose=False)
pipeline = Pipeline([
    ('scaler', StandardScaler(with_mean=False)),
    ('regressor', model)
])
param_grid = {
    'scaler': [StandardScaler(with_mean=False), None],
    'regressor__iterations': [100, 200], 
    'regressor__learning_rate': [0.01, 0.1],
    'regressor__depth': [4, 6]
}
models[model_name] = create_model(pipeline, param_grid, features_train, target_train)
print(f'Модель {model_name}')
print('-' * 70)
print(f'Время обучения: {models[model_name]["training_time"]} сек.')
print(f'Время предсказания: {models[model_name]["prediction_time"]} сек.')
print(f'RMSE: {models[model_name]["rmse"]}')
# print(f'Лучшая модель:{models[model_name]["best_model"]}')
print('-' * 70);
# Out:
# Модель CatBoostRegressor
# ----------------------------------------------------------------------
# Время обучения: 151.02 сек.
# Время предсказания: 0.01 сек.
# RMSE: 22.54576
# ----------------------------------------------------------------------
# CPU times: user 2min 4s, sys: 1.29 s, total: 2min 5s
# Wall time: 2min 31s

# %% [markdown]
# ### Промежуточные выводы

# %% [markdown]
# **Обучено 4 модели:**
# * `LinearRegression` - линейная регрессия,
# * `DecisionTreeRegressor` - дерево решений,
# * `LGBMRegressor` - градиентный бустинг.
# * `CatBoostRegressor` - градиентный бустинг.

# %% [markdown]
# ## Анализ моделей

# %% [markdown]
# ### Сравнение моделей

# %%
# Cформируем таблицу с результати
columns=['model', 'rmse', 'training_time', 'prediction_time']
keys = list(models.keys())
data = []
for key in models.keys():
    data.append([
            key,
            models[key]['rmse'],
            models[key]['training_time'], 
            models[key]['prediction_time']
       ])
results_df = pd.DataFrame(data=data, columns=columns).sort_values(by=['rmse']);

# %%
# Покажем таблицу с результати обучения и предсказаниями модели 
display(results_df);
# Out:
#                    model      rmse  training_time  prediction_time
# 3      CatBoostRegressor  22.54576         151.02             0.01
# 0       LinearRegression  22.54985           6.54             0.00
# 2          LGBMRegressor  23.12004         522.77             0.08
# 1  DecisionTreeRegressor  27.64537          10.12             0.00

# %%
# Покажем диаграмму сравнения моделей по времени обучения
show_barplot(
    'Сравнение моделей по времени обучения',
    results_df['model'],
    results_df['training_time'],
    '',
    'Время обучения, сек.'
)
# Покажем диаграмму сравнения моделей по времени предсказания
show_barplot(
    'Сравнение моделей по времени предсказания',
    results_df['model'],
    results_df['prediction_time'],
    '',
    'Время предсказания, сек.'
)
# Покажем диаграмму сравнения моделей по RMSE
plt.figure(figsize=(12, 6))
ax = sns.barplot(x=results_df['model'], y=results_df['rmse']) 
plt.suptitle('Сравнение моделей по RMSE', fontsize=16, ha='center')
ax.set_xlabel('')
ax.set_ylabel('Значение RMSE')
# добавим линию "отсечки" с целевым RMSE 48
ax.axhline(y = 48, color = 'red', label = 'заданный уровень RMSE', linestyle='dashed')
plt.legend(loc='upper left')
ax.bar_label(ax.containers[0],
             color='black',
             fontsize=12,
             fontweight='bold')
plt.show();

# %% [markdown]
# ### Промежуточные выводы

# %% [markdown]
# **Результаты сравнения моделей:**
# * Лучшей моделью по метрике `RMSE` является `CatBoostRegressor` с незначительным превосходством над `LinearRegressor`.
# * Худшей моделью по времени предсказания является `LGBMRegressor`.
# * Лvчшей моделью по времени обучения является `LinearRegressor`.
# * Все модели удовлетворяют целевому значению метрики `RMSE` < 48.
#
# **Так как, для заказчика первично качество предсказания модели, то в качестве лучшей модели выберем `CatBoostRegressor`, которая имеет лучшее значение `RMSE`, несмотря на более длительное время обучения.**

# %% [markdown]
# ## Тестирование

# %% [markdown]
# ### Проверка лучшей модели на тестовых данных

# %%
# %%time
predictions_test = models['CatBoostRegressor']['best_model'].predict(features_test)
rmse_test = round(mean_squared_error(target_test, predictions_test, squared=False), 5)
print(f'RMSE на тестовой выборке: {rmse_test}')
print('-' * 70);
# Out:
# RMSE на тестовой выборке: 37.50189
# ----------------------------------------------------------------------
# CPU times: user 11.5 ms, sys: 39 µs, total: 11.6 ms
# Wall time: 10.5 ms

# %% [markdown]
# **Метрика `RMSE` на тестовых данных хуже чем на тренировочных. Вместе с тем, она удовлетворяет целевому уровню < 48.**

# %% [markdown]
# ### Сравнение предсказаний с реальными значениями

# %%
# Подготовим датасет тестовых данных
df = pd.DataFrame(target_test)
# Добавим предсказания модели
df['prediction'] = predictions_test
# Выведем график
plt.figure(figsize=(16, 8))
plt.plot(df['num_orders'], label='Реальные значения', color='green')
plt.plot(df['prediction'], label='Предсказания', color='yellow')
plt.title('Сравнение предсказаний с реальными значениями')
plt.xlabel('Дата')
plt.ylabel('Количество заказов')
plt.legend()
plt.grid(True)
plt.show();

# %% [markdown]
# На графике заметно, что за исключением некоторых выбросов предсказанные значения близки к реальным.

# %% [markdown]
# ## Итоговые выводы

# %% [markdown]
# ### Отчет о проделанной работе

# %% [markdown]
# **Цель данного проекта - построить модель для предсказания количество заказов такси на следующий час.**
#
# **В ходе загрузки и изучения данных:**
# * Проведена загрузка и ресемплирование данных по 1 часу.
# * В ходе изучения данных выявили, что:
#     - Пропуски в данных не выявлены.
#
# **После анализа данных можем сделать следующие выводы:**
# * Наблюдения проводились с 1 марта по 31 августа 2018 года.*
# * Минимальное количество заказов такси в час составляло 0, максимальное - 462, медианное - 78.
# * На графиках можно наблюдать, что линия тренда растет и достигает пика в конце августа. Вероятно это связано с окончанием сезона отпусков.
# * На графике сезонности нельзя увидеть все закономерности, так как есть данные только за 6 месяцев. Тем не менее, можно отметить, что основные колебания происходят в течение каждого дня.
# * На однодневном графике заметно, что пик заказов такси приходится на ночное время - примерно с 23:00 до 02:00, существенный спад наблюдается в 6 утра. В ночные часы вероятно не работает общественный транспорт. С 6 утра скорее всего он начинает работать и пока на нем невысокая загрузка, поэтому падает спрос на такси.
# * По графику распределения заказов заметно, что это скорее нестационарный временной ряд, так как со временем меняются среднее и стандартное отклонение. Наблюдается рост среднего и стандартного отклонения.
#
# **Обучено 4 модели:**
# * `LinearRegression` - линейная регрессия,
# * `DecisionTreeRegressor` - дерево решений,
# * `LGBMRegressor` - градиентный бустинг.
# * `CatBoostRegressor` - градиентный бустинг.
#
# **Результаты сравнения моделей:**
# * Лучшей моделью по метрике `RMSE` является `CatBoostRegressor` с незначительным превосходством над `LinearRegressor`.
# * Худшей моделью по времени предсказания является `LGBMRegressor`.
# * Лvчшей моделью по времени обучения является `LinearRegressor`.
# * Все модели удовлетворяют целевому значению метрики `RMSE` < 48.
#
# **Вывод: так как, для заказчика первично качество предсказания модели, то в качестве лучшей модели выберем `CatBoostRegressor`, которая имеет лучшее значение `RMSE`, несмотря на более длительное время обучения.**
#
# **Проведена проверка лучшей модели на тестовых данных. Метрика `RMSE` на тестовых данных хуже чем на тренировочных. Вместе с тем, она удовлетворяет целевому уровню < 48.**
#
# **Проведено графическое сравнение предсказанных и реальных значений. На графике заметно, что за исключением некоторых выбросов предсказанные значения близки к реальным.**

# %% [markdown]
# ### Выводы

# %% [markdown]
# 1. **По результатам оценки определено, что наилучшие показатели продемонстрировала модель `CatBoostRegressor`.**
#
# 2. **Модель сохранена в переменной `models['CatBoostRegressor']['best_model']`**.
#
# 3. **Модель рекомендована заказчику для пронозирования количества заказов такси на следующий час.**
