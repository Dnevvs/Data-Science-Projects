# %% [markdown]
# # Определение стоимости автомобилей

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span><ul class="toc-item"><li><span><a href="#Цель-проекта" data-toc-modified-id="Цель-проекта-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Цель проекта</a></span></li><li><span><a href="#Постановка-задачи" data-toc-modified-id="Постановка-задачи-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Постановка задачи</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Описание данных</a></span></li></ul></li><li><span><a href="#Загрузка-необходимых-библиотек-и-функций" data-toc-modified-id="Загрузка-необходимых-библиотек-и-функций-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Загрузка необходимых библиотек и функций</a></span></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Изучение-данных" data-toc-modified-id="Изучение-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Изучение данных</a></span><ul class="toc-item"><li><span><a href="#Формирование-и-изучение-отчета-о-данных" data-toc-modified-id="Формирование-и-изучение-отчета-о-данных-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Формирование и изучение отчета о данных</a></span></li><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Устранение-явных-дубликатов" data-toc-modified-id="Устранение-явных-дубликатов-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Устранение явных дубликатов</a></span></li><li><span><a href="#Устранение-пропусков" data-toc-modified-id="Устранение-пропусков-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Устранение пропусков</a></span></li><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Подготовка-необходимых-данных" data-toc-modified-id="Подготовка-необходимых-данных-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Подготовка необходимых данных</a></span></li><li><span><a href="#Статистический-анализ-всех-признаков." data-toc-modified-id="Статистический-анализ-всех-признаков.-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Статистический анализ всех признаков.</a></span></li><li><span><a href="#Корреляционный-анализ" data-toc-modified-id="Корреляционный-анализ-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Корреляционный анализ</a></span></li><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Деление-на-выборки" data-toc-modified-id="Деление-на-выборки-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Деление на выборки</a></span></li><li><span><a href="#Тестирование-моделей" data-toc-modified-id="Тестирование-моделей-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Тестирование моделей</a></span><ul class="toc-item"><li><span><a href="#Линейная-регрессия-LinearRegression" data-toc-modified-id="Линейная-регрессия-LinearRegression-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>Линейная регрессия <code>LinearRegression</code></a></span></li><li><span><a href="#Дерево-решений-DecisionTreeRegressor" data-toc-modified-id="Дерево-решений-DecisionTreeRegressor-7.2.2"><span class="toc-item-num">7.2.2&nbsp;&nbsp;</span>Дерево решений <code>DecisionTreeRegressor</code></a></span></li><li><span><a href="#Градиентный-бустинг-LGBMRegressor" data-toc-modified-id="Градиентный-бустинг-LGBMRegressor-7.2.3"><span class="toc-item-num">7.2.3&nbsp;&nbsp;</span>Градиентный бустинг <code>LGBMRegressor</code></a></span></li></ul></li></ul></li><li><span><a href="#Анализ-моделей" data-toc-modified-id="Анализ-моделей-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Анализ моделей</a></span><ul class="toc-item"><li><span><a href="#Сравнение-моделей" data-toc-modified-id="Сравнение-моделей-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Сравнение моделей</a></span></li><li><span><a href="#Проверка-лучшей-модели-на-тестовых-данных" data-toc-modified-id="Проверка-лучшей-модели-на-тестовых-данных-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Проверка лучшей модели на тестовых данных</a></span></li><li><span><a href="#Анализ-важности-признаков" data-toc-modified-id="Анализ-важности-признаков-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Анализ важности признаков</a></span></li><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li><li><span><a href="#Итоговые-выводы" data-toc-modified-id="Итоговые-выводы-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Итоговые выводы</a></span><ul class="toc-item"><li><span><a href="#Отчет-о-проделанной-работе" data-toc-modified-id="Отчет-о-проделанной-работе-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Отчет о проделанной работе</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# ### Цель проекта

# %% [markdown]
# Цель данного проекта - построить модель для определения рыночной стоимости автомобилей.

# %% [markdown]
# ### Постановка задачи

# %% [markdown]
# Сервис по продаже автомобилей с пробегом «Не бит, не крашен» разрабатывает приложение для привлечения новых клиентов. В нём можно быстро узнать рыночную стоимость своего автомобиля. В нашем распоряжении исторические данные: технические характеристики, комплектации и цены автомобилей. Нам нужно построить модель для определения стоимости.
#
# Заказчику важны:
# - качество предсказания;
# - скорость предсказания;
# - время обучения.

# %% [markdown]
# ### Описание данных

# %% [markdown]
# Данные находятся в файле `/datasets/autos.csv`.
#
# Признаки
# * `DateCrawled` — дата скачивания анкеты из базы.
# * `VehicleType` — тип автомобильного кузова.
# * `RegistrationYear` — год регистрации автомобиля.
# * `Gearbox` — тип коробки передач.
# * `Power` — мощность (л. с.).
# * `Model` — модель автомобиля.
# * `Kilometer` — пробег (км).
# * `RegistrationMonth` — месяц регистрации автомобиля.
# * `FuelType` — тип топлива.
# * `Brand` — марка автомобиля.
# * `Repaired` — была машина в ремонте или нет.
# * `DateCreated` — дата создания анкеты.
# * `NumberOfPictures` — количество фотографий автомобиля.
# * `PostalCode` — почтовый индекс владельца анкеты (пользователя).
# * `LastSeen` — дата последней активности пользователя.
#
# Целевой признак
# * `Price` — цена (евро).

# %% [markdown]
# ##  Загрузка необходимых библиотек и функций

# %%
! pip install catboost -q
! pip install lightgbm -q
! pip install matplotlib==3.4.2 -q
! pip install missingno -q
! pip install phik -q
! pip install numba==0.57.1 -q
! pip install numpy==1.23 -q
! pip install pandas==2.0.3 -q
! pip install -U scikit-learn -q
! pip install seaborn==0.12.2 -q
! pip install shap==0.44.1 -q;

# %%
# Загрузим библиотеки
import os
import warnings

import numpy as np
import pandas as pd
import seaborn as sns
import time
from lightgbm import LGBMRegressor
from matplotlib import pyplot as plt
from numpy.random import RandomState
from pandas.api.types import is_string_dtype
from scipy import stats as st
from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import (accuracy_score, confusion_matrix, make_scorer,
                             mean_absolute_error, mean_squared_error,
                             precision_score, r2_score, recall_score, roc_auc_score,
                             root_mean_squared_error)
from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, RobustScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor

import missingno as msno
import phik
import shap 

warnings.filterwarnings('ignore');

# %%
RANDOM_STATE = 42
STATE = RandomState(12345)

# %%
def df_research_method(df, method):
    """
    Применяет определенный метод изучения данных в датасете.

    Параметры:
    - df: Исследуемый датасет.
    - method: Название метода.
   
    Пример:
    ```
    df_research_method(df, 'head')
    ```
    """
    
    if method == 'head':
        display(df.head())
    elif method == 'shape':
        display(df.shape)
    elif method == 'describe':
        display(df.describe().T)
    elif method == 'duplicated':
        dp = df.duplicated().sum()
        display(dp)
        if dp > 0:
            print('Количество явных дубликатов:')
            display(df[df.duplicated()])
    elif method == 'unique':
        for column in df.select_dtypes(include='object').columns:
            print(f'Уникальные значения в колонке {column}: {df[column].sort_values().unique()}')
    elif method == 'msno':
        display(msno.bar(df))
        plt.show()
    else:
        display(df.info())

# Функция применения методов к списку датасетов
def df_research(df_list, df_methods):
    """
    Применяет метод из списка для изучения данных в списке датасетов.

    Параметры:
    - df_list: Список исследуемых датасетов (имя переменной, описание, имя файла).
    - df_method: Список названий методов.
   
    Пример:
    ```
    df_research(df_list, df_methods)
    ```
    """
    
    for method in df_methods:
        print(f'Изучим {method[1]}:')
        print('-' * 70)
        for df in df_list:
            globals()[df[0]] = globals()[df[0]].applymap(lambda x: x.lower() if isinstance(x, str) else x)
            print('Dataset:', df[1])
            print('-' * 70)
            df_research_method(globals()[df[0]], method[0])
            print('-' * 70);

# %%
# Функция для отображения количественного признака    
def show_numeric_feature(df, column, title, x_label, y_label):
    """
    Отображает гистограмму и "ящик с усами" для количественного признака.

    Параметры:
    - df: Датасет.
    - column: Название колонки признака.
    - title: Заголовок диаграммы.
    - x_label: Название оси X.
    - y_label: Название оси Y.
   
    Пример:
    ```
    show_numeric_feature(market_file_df, 
                         'выручка',
                         'Выручка за период',
                         'Выручка',
                         'Количество покупателей')
    ```
    """
    
    fig, axes = plt.subplots(1, 2, figsize=(18, 6))
    plt.suptitle(title.upper(), fontsize=16, ha='center')
    sns.histplot(data=df[column], color='g', kde=False, ax=axes[0], bins=30) 
    axes[0].set_xlabel(x_label)
    axes[0].set_ylabel(y_label)
    sns.boxplot(x=df[column], color='c')
    axes[1].set_xlabel(y_label)
    plt.show()
    print('Описание признака:', x_label)
    display(df[column].describe().T)
    
# Функция для расчета % ТОП-категорий
def top_pie(pct, local, total):
    res = (pct * local) / total 
    return f"{res:.1f}%"
   
# Функция для отображения категориального признака    
def show_categorical_feature(df, column, title, x_label, y_label, num=None):
    """
    Отображает столбчатую и круговую диаграммы для категориального признака.

    Параметры:
    - df: Датасет.
    - column: Название колонки признака.
    - title: Заголово диаграммы.
    - x_label: Название оси X.
    - y_label: Название оси Y.
    - num: количество ТОП-категорий.
   
    Пример:
    ```
    show_categorical_feature(market_file_df, 
                         'покупательская_активность',
                         'класс покупательской активности',
                         'Покупательская активность',
                         'Количество покупателей',
                         10)
    ```
    """
    
    cat_df = df[column].value_counts()
    labels = cat_df.index
    if num:
        cat_df = cat_df[:num]
        labels = labels[:num]
          
   
    fig, axes = plt.subplots(1, 2, figsize=(18, 6))
    plt.suptitle(title.upper(), fontsize=16, ha='center')
    sns.barplot(x=labels,
                y=cat_df,
                color='g',
                ax=axes[0]) 
    axes[0].set_xlabel(x_label)
    axes[0].set_ylabel(y_label)
    axes[0].tick_params(labelrotation=90)
    axes[0].bar_label(axes[0].containers[0],
                      padding=-25,
                      color='white',
                      fontsize=12,
                      label_type='edge',
                      fontweight='bold')

    
    if num:
        total = len(df[column])
        local = sum(cat_df)
        plt.pie(cat_df, 
                labels=labels, 
                autopct=lambda pct: top_pie(pct, local, total), 
                wedgeprops = { 'linewidth': 3, 'edgecolor': 'white' })
    else:
        plt.pie(cat_df, 
                labels=labels, 
                autopct='%1.1f%%', 
                wedgeprops = { 'linewidth': 3, 'edgecolor': 'white' })
    axes[1].set_xlabel(x_label)
    plt.show()
    
# Функция для отображения количественного признака по списку
def show_numeric_feature_by_list(df, features):
    """
    Отображает гистограмму и "ящик с усами" для количественного признака
    по списку.

    Параметры:
    - df: Датасет.
    - features: Список признаков для отображения.
   
    Пример:
    ```
    show_numeric_feature_by_list(market_file_df, 
        market_file_numeric_features)
    ```
    """
    
    for feature in features:
        title = feature[2]
        column = feature[0]
        x_label = feature[1]
        y_label = 'Количество'
        show_numeric_feature(df, column, title, x_label, y_label);
        
# Функция для отображения категориального признака по списку
def show_categorical_feature_by_list(df, features, num=None):
    """
    Отображает столбчатую и круговую диаграммы для категориального признака
    по списку

    Параметры:
    - df: Датасет.
    - features: Список признаков для отображения.
   
    Пример:
    ```
    show_categorical_feature_by_list(market_file_df, 
        market_file_categorical_features)
    ```
    """

    for feature in features:
        title = feature[2]
        column = feature[0]
        x_label = feature[1]
        y_label = 'Количество' 
        show_categorical_feature(df, column, title, x_label, y_label, num);

# %%
def show_barplot(title, x, y, x_label, y_label):
    ax = sns.barplot(x=x, y=y) 
    plt.suptitle(title, fontsize=16, ha='center')
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.bar_label(ax.containers[0],
                 padding=-25,
                 color='white',
                 fontsize=12,
                 label_type='edge',
                 fontweight='bold')
    plt.show();

# %%
# создадим функцию для построения диаграммы корреляции признаков
def corr_matrix(data, columns, interval_cols):
    """
    Отображает матрицу кореляции.

    Параметры:
    - data: Датасет.
    - columns: Названия колонок.
    - interval_cols: Числовые колонки.
    
   
    Пример:
    ```
    corr_matrix(data, columns, interval_cols)
    ```
    """
    
    # сформируем матрицу корреляции
    corr_matrix = data[columns].phik_matrix(interval_cols=interval_cols)
    # построим тепловую карту
    plt.figure(figsize=(18, 12))
    sns.heatmap(corr_matrix, 
                annot=True, 
                linewidths=0.5, 
                cmap='coolwarm')
    plt.show();

# %%
def show_barplot(title, x, y, x_label, y_label):
    ax = sns.barplot(x=x, y=y) 
    plt.suptitle(title, fontsize=16, ha='center')
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.bar_label(ax.containers[0],
                 padding=-25,
                 color='white',
                 fontsize=12,
                 label_type='edge',
                 fontweight='bold')
    plt.show();

# %% [markdown]
# ## Загрузка данных

# %%
# Список датасетов для загрузки - 
# имя переменной датасета, описание датасета, имя файла
datasets = [
    ['autos', 'Данные об автомобилях', 'autos.csv', ['DateCrawled', 'DateCreated', 'LastSeen']]
]

# Пути для загрузки
dir_1 = '/datasets/'
dir_2 = 'https://code.s3.yandex.net/datasets/';

# %%
# Проведем загрузку
for df in datasets:
    path_1 = f'{dir_1}{df[2]}'
    path_2 = f'{dir_2}{df[2]}'
    if os.path.exists(path_1):
        globals()[df[0]] = pd.read_csv(path_1, sep=',', decimal='.', parse_dates=df[3])
    elif os.path.exists(pth2):
        globals()[df[0]] = pd.read_csv(path_2, sep=',', decimal='.', parse_dates=df[3])
    else:
        print(f'Ошибка загрузки датасета "{df[1]}"')
        break
    print(f'Датасет "{df[1]}" загружен 100%');
# Out:
# Датасет "Данные об автомобилях" загружен 100%

# %% [markdown]
# ## Изучение данных

# %% [markdown]
# ### Формирование и изучение отчета о данных

# %% [markdown]
# Подготовим спискок методов изучения данных:

# %%
df_methods = [['info', 'общую информацию о датасете'],
              ['head', 'первые записи датасета'],
              ['shape', 'размеры датасета'],
              ['describe', 'описание полей датасета'],
              ['duplicated', 'явные дубликаты'],
              ['msno', 'пропуски']
             ];

# %% [markdown]
# Изучим данные:

# %%
df_research(datasets, df_methods);
# Out:
# Изучим общую информацию о датасете:
# ----------------------------------------------------------------------
# Dataset: Данные об автомобилях
# ----------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        354369 non-null  datetime64[ns]
#  1   Price              354369 non-null  int64
#  2   VehicleType        316879 non-null  object
#  3   RegistrationYear   354369 non-null  int64
#  4   Gearbox            334536 non-null  object
#  5   Power              354369 non-null  int64
#  6   Model              334664 non-null  object
#  7   Kilometer          354369 non-null  int64
#  8   RegistrationMonth  354369 non-null  int64
#  9   FuelType           321474 non-null  object
#  10  Brand              354369 non-null  object
# ...

# %% [markdown]
# ### Промежуточные выводы

# %% [markdown]
# В ходе изучения данных выявили, что:
# - Выявлены явные дубликаты.
# - Выявлены пропуски в данных.
# - Нотацию названий колонок оставим в формате PascalCase.

# %% [markdown]
# ##  Предобработка данных

# %% [markdown]
# ### Устранение явных дубликатов

# %%
# Удаление дубликатов
autos.drop_duplicates(inplace=True);

# %%
# Проверка результата
print(f'Количество явных дубликатов: {autos.duplicated().sum()}');
# Out:
# Количество явных дубликатов: 0

# %% [markdown]
# ### Устранение пропусков

# %% [markdown]
# На стадии исследования данных пропуски были обнаружены в следующих признаках:

# %%
# Список признаков с пропусками
features_nan = [
    ['VehicleType', 'Тип кузова', ''],
    ['Gearbox', 'Тип КПП', ''],
    ['Model', 'Модель', ''],
    ['FuelType', 'Тип топлива', ''],
    ['Repaired', 'Ремонт (yes/no)', '']
];

# %%
# Проверим уникальные значения всех признаков
for feature in features_nan:
    print(feature[1])
    f_list = autos[feature[0]].sort_values().unique()
    print(f_list)
    print('-' * 70);
# Out:
# Тип кузова
# ['bus' 'convertible' 'coupe' 'other' 'sedan' 'small' 'suv' 'wagon' nan]
# ----------------------------------------------------------------------
# Тип КПП
# ['auto' 'manual' nan]
# ----------------------------------------------------------------------
# Модель
# ['100' '145' '147' '156' '159' '1_reihe' '1er' '200' '2_reihe' '300c'
#  '3_reihe' '3er' '4_reihe' '500' '5_reihe' '5er' '601' '6_reihe' '6er'
#  '7er' '80' '850' '90' '900' '9000' '911' 'a1' 'a2' 'a3' 'a4' 'a5' 'a6'
#  'a8' 'a_klasse' 'accord' 'agila' 'alhambra' 'almera' 'altea' 'amarok'
#  'antara' 'arosa' 'astra' 'auris' 'avensis' 'aveo' 'aygo' 'b_klasse'
#  'b_max' 'beetle' 'berlingo' 'bora' 'boxster' 'bravo' 'c1' 'c2' 'c3' 'c4'
#  'c5' 'c_klasse' 'c_max' 'c_reihe' 'caddy' 'calibra' 'captiva' 'carisma'
#  'carnival' 'cayenne' 'cc' 'ceed' 'charade' 'cherokee' 'citigo' 'civic'
#  'cl' 'clio' 'clk' 'clubman' 'colt' 'combo' 'cooper' 'cordoba' 'corolla'
# ...

# %% [markdown]
# * Пропуски в `типе кузова`, `модели автомобиля`, `типе топлива` могли возникнуть в связи с отсутствием исходных значений в информационной системе сервиса. Присвоим пропущенным значениям этих признаков значение `other`.
# * Пропуски в `типе КПП` возможно возникли по каким-либо техническим причинам или из-за человеческого фактора. Обоснованить замену нечем, поэтому присвоим пропущенным значениям - `unknown`.
# * Пропуски в `информации о ремонте` вероятно обозначают то, что ремонт не проводился. Присвоим пропущенным значениям - `no`.
#
# Дополним список информацией о подставляемых значениях:

# %%
# Список признаков с пропусками
features_nan = [
    ['VehicleType', 'Тип кузова', 'other'],
    ['Gearbox', 'Тип КПП', 'unknown'],
    ['Model', 'Модель', 'other'],
    ['FuelType', 'Тип топлива', 'other'],
    ['Repaired', 'Ремонт (yes/no)', 'unknown']
];

# %%
# Проведем замену
for feature in features_nan:
    autos[feature[0]].fillna(feature[2], inplace=True)
# Проверка результата
display(msno.bar(autos))
plt.show();
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Промежуточные выводы

# %% [markdown]
# В ходе предобработки данных:
#
# - Устранены явные дубликаты.
# - Устранены пропуски в данных.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Подготовка необходимых данных

# %%
# Списки признаков для анализа
# в формате - признак, название, комментарий
# Общий список признаков
df_features = [
    ['DateCrawled', 'Дата скачивания анкеты', 'дата скачивания анкеты из базы'],
    ['Price', 'Цена, EUR', 'цена (евро)'],    
    ['VehicleType', 'Тип кузова', 'тип автомобильного кузова'],
    ['RegistrationYear', 'Год регистрации', 'год регистрации автомобиля'],
    ['Gearbox', 'Тип КПП', 'тип коробки передач'],
    ['Power', 'Мощность, л.с.', 'мощность (л. с.)'],
    ['Model', 'Модель', 'модель автомобиля'],
    ['Kilometer', 'Пробег, км.', 'пробег (км)'],
    ['RegistrationMonth', 'Месяц регистрации', 'месяц регистрации автомобиля'],
    ['FuelType', 'Тип топлива', 'тип топлива'],
    ['Brand', 'Марка', 'марка автомобиля'],
    ['Repaired', 'Ремонт (yes/no)', 'была машина в ремонте или нет'],
    ['DateCreated', 'Дата анкеты', 'дата создания анкеты'],
    ['NumberOfPictures', 'Кол-во фото', 'количество фотографий автомобиля'],
    ['PostalCode', 'Почтовый индекс', 'почтовый индекс владельца анкеты (пользователя)'],
    ['LastSeen', 'Дата последней активности', 'дата последней активности пользователя']
]

# Подробный список количественных призаков
df_numeric_features = [
    ['Price', 'Цена, EUR', 'цена (евро)'],    
    ['RegistrationYear', 'Год регистрации', 'год регистрации автомобиля'],
    ['Power', 'Мощность, л.с.', 'мощность (л. с.)'],
    ['Kilometer', 'Пробег, км.', 'пробег (км)'],
    ['RegistrationMonth', 'Месяц регистрации', 'месяц регистрации автомобиля'],
    ['NumberOfPictures', 'Кол-во фото', 'количество фотографий автомобиля']
]

# Список числовых признаков
# df_num_columns = globals()[datasets[0][0]].select_dtypes(include='number').columns.tolist()
# print('Список числовых признаков\n', df_num_columns)
df_num_columns = ['Price', 'RegistrationYear', 'Power', 'Kilometer', 'RegistrationMonth', 'NumberOfPictures']

# Подробный список категориальных призаков
df_categorical_features = [
    ['DateCrawled', 'Дата скачивания анкеты', 'дата скачивания анкеты из базы'],
    ['VehicleType', 'Тип кузова', 'тип автомобильного кузова'],
    ['Gearbox', 'Тип КПП', 'тип коробки передач'],
    ['Model', 'Модель', 'модель автомобиля'],
    ['FuelType', 'Тип топлива', 'тип топлива'],
    ['Brand', 'Марка', 'марка автомобиля'],
    ['Repaired', 'Ремонт (yes/no)', 'была машина в ремонте или нет'],
    ['DateCreated', 'Дата анкеты', 'дата создания анкеты'],
    ['PostalCode', 'Почтовый индекс', 'почтовый индекс владельца анкеты (пользователя)'],
    ['LastSeen', 'Дата последней активности', 'дата последней активности пользователя']
];

# %% [markdown]
# ### Статистический анализ всех признаков.

# %%
# Анализ количественных признаков
for df in datasets:
    print('Dataset:', df[1])
    show_numeric_feature_by_list(globals()[df[0]], df_numeric_features);
# Out:
# Dataset: Данные об автомобилях
# Описание признака: Цена, EUR
# count    354365.000000
# mean       4416.679830
# std        4514.176349
# min           0.000000
# 25%        1050.000000
# 50%        2700.000000
# 75%        6400.000000
# max       20000.000000
# Name: Price, dtype: float64
# Описание признака: Год регистрации
# count    354365.000000
# mean       2004.234481
# std          90.228466
# min        1000.000000
# 25%        1999.000000
# 50%        2003.000000
# 75%        2008.000000
# max        9999.000000
# Name: RegistrationYear, dtype: float64
# Описание признака: Мощность, л.с.
# count    354365.000000
# mean        110.093816
# std         189.851330
# min           0.000000
# 25%          69.000000
# 50%         105.000000
# 75%         143.000000
# max       20000.000000
# Name: Power, dtype: float64
# Описание признака: Пробег, км.
# count    354365.000000
# mean     128211.363989
# std       37905.083858
# min        5000.000000
# 25%      125000.000000
# ...

# %% [markdown]
# Рассмотрим аномалии в данных:

# %%
print('Аномалии по цене (нижняя граница 50 EUR):')
display(autos.query('Price < 50').sample(10))
print('Аномалии по году регистрации (наибольшая динамика производства началась в 1970-х годах):')
display(autos.query('RegistrationYear < 1970 or RegistrationYear > 2016').sample(10))
print('Аномалии по мощности:')
display(autos.query('Power < 40 or Power > 800').sample(10));
# Out:
# Аномалии по цене (нижняя граница 50 EUR):
#                DateCrawled  Price VehicleType  RegistrationYear  Gearbox  \
# 36770  2016-03-31 16:52:26      0       coupe              1992   manual
# 55207  2016-03-08 20:49:02      1       coupe              2002   manual
# 294100 2016-03-13 20:25:23      0         bus              1996   manual
# 181909 2016-03-11 16:51:32      0       other              2005   manual
# 349552 2016-03-27 20:55:09      0       other              2006  unknown
# 275637 2016-03-24 02:02:38      0       sedan              2006     auto
# 123471 2016-04-03 00:57:35      0       wagon              2003     auto
# 11386  2016-03-27 16:57:28     17       other              2005  unknown
# 274475 2016-03-31 22:58:13      1       other              1990  unknown
# 1649   2016-04-02 15:38:40      0       small              2001     auto
#
#         Power    Model  Kilometer  RegistrationMonth  FuelType  \
# ...

# %%
# Сохраним исходное количество записей датасета
start_len = autos.shape[0];

# %% [markdown]
# Исключим из дальнейшего анализа автомобили, цена которых составляет менее 50 евро. Возможно это ошибки в данных.

# %%
autos = autos.query('Price >= 50');

# %% [markdown]
# Присутствуют аномалии по году регистрации автомобиля.
# Для дальнейшего анализа оставим только те автомобили, которые были зарегистрированы в период с 1970 по 2016 год.

# %%
autos = autos.query('RegistrationYear >= 1970 and RegistrationYear <= 2016');

# %% [markdown]
# Уберём аномальные значения по мощности двигателя - установим границы от 40 до 800 лошадиных сил и заменим аномалии на медианные значения по каждой модели:

# %%
for model in autos['Model'].unique():
    index_1 = autos.query('(Power < 40 or Power > 800) & Model==@model').index
    index_2 = autos.query('Model==@model').index
    autos.loc[index_1, 'Power'] = autos.loc[index_2, 'Power'].median();

# %%
# Удалим возможно оставшиеся аномалии
autos = autos.query('Power >= 40 and Power <= 800');

# %%
# Сохраним итоговое количество записей датасета
end_len = autos.shape[0]
# Покажем результат обрабоки аномалий
print(f'Удалено {start_len-end_len} записей - {round(((start_len - end_len) / start_len) * 100,2)}% данных.');
# Out:
# Удалено 27776 записей - 7.84% данных.

# %% [markdown]
# Повторим анализ доработанного списка количественных признаков:

# %%
# Список доработанных количественных призаков
df_numeric_features_new = [
    ['Price', 'Цена, EUR', 'цена (евро)'],    
    ['RegistrationYear', 'Год регистрации', 'год регистрации автомобиля'],
    ['Power', 'Мощность, л.с.', 'мощность (л. с.)']
]
# Анализ количественных признаков
for df in datasets:
    print('Dataset:', df[1])
    show_numeric_feature_by_list(globals()[df[0]], df_numeric_features_new);
# Out:
# Dataset: Данные об автомобилях
# Описание признака: Цена, EUR
# count    326589.000000
# mean       4619.814764
# std        4537.611326
# min          50.000000
# 25%        1200.000000
# 50%        2950.000000
# 75%        6650.000000
# max       20000.000000
# Name: Price, dtype: float64
# Описание признака: Год регистрации
# count    326589.000000
# mean       2002.784454
# std           6.344181
# min        1970.000000
# 25%        1999.000000
# 50%        2003.000000
# 75%        2007.000000
# max        2016.000000
# Name: RegistrationYear, dtype: float64
# Описание признака: Мощность, л.с.
# count    326589.000000
# mean        119.434655
# std          52.631371
# min          40.000000
# 25%          77.000000
# 50%         109.000000
# 75%         145.000000
# max         800.000000
# Name: Power, dtype: float64

# %% [markdown]
# **После анализа количественных признаков и исключения аномальных значений мы можем сделать следующие выводы:**
# * `Цена` варьируются от 50 до 20 000 EUR, с медианным значением в 2900 EUR. Распределение смещено влево.
# * `Год регистрации` варьируется от 1970 до 2016 г., с медианным значением 2003. Распределение смещено вправо.
# * `Мощность` варьируется от 40 до 800 л.с. с медианой в 109 л.с. Распределение смещено влево.
# * `Пробег` варьируется от 5000 до 150 000 км, с медианным значением в 150000 км. Заметно преобладание машин с большим пробегом..Распределение дискретное с небольшим количеством значений. Перенесем признак в категориальные .
# * `Месяц регистрации` - практичеси равномерное распределени, исключим его из дальнейшего анализа.
# * `Количество фотографий` - полностью отсутствуют значения. Вероятно, это связано с ошибкой при выгрузке данных. Исключим его из дальнейшего анализа.

# %%
# Подробный список количественных призаков
df_numeric_features = [
    ['Price', 'Цена, EUR', 'цена (евро)'],    
    ['RegistrationYear', 'Год регистрации', 'год регистрации автомобиля'],
    ['Power', 'Мощность, л.с.', 'мощность (л. с.)'],
    ['RegistrationMonth', 'Месяц регистрации', 'месяц регистрации автомобиля'],
    ['NumberOfPictures', 'Кол-во фото', 'количество фотографий автомобиля']
]

# Список числовых признаков
df_num_columns = ['Price', 'RegistrationYear', 'Power']


# Подробный список категориальных призаков
df_categorical_features = [
    ['DateCrawled', 'Дата скачивания анкеты', 'дата скачивания анкеты из базы'],
    ['VehicleType', 'Тип кузова', 'тип автомобильного кузова'],
    ['Gearbox', 'Тип КПП', 'тип коробки передач'],
    ['Model', 'Модель', 'модель автомобиля'],
    ['Kilometer', 'Пробег, км.', 'пробег (км)'],
    ['FuelType', 'Тип топлива', 'тип топлива'],
    ['Brand', 'Марка', 'марка автомобиля'],
    ['Repaired', 'Ремонт (yes/no)', 'была машина в ремонте или нет'],
    ['DateCreated', 'Дата анкеты', 'дата создания анкеты'],
    ['PostalCode', 'Почтовый индекс', 'почтовый индекс владельца анкеты (пользователя)'],
    ['LastSeen', 'Дата последней активности', 'дата последней активности пользователя']
];

# %%
# Анализ категориальныз признаков
# Для признаков с большим количество категорий рассмотрим ТОП-10 категорий.
for df in datasets:
    print('Dataset:', df[1])
    show_categorical_feature_by_list(globals()[df[0]], df_categorical_features, 10);
# Out:
# Dataset: Данные об автомобилях

# %% [markdown]
# **Исходя из анализа категориальных признаков, можно отметить следующее:**
# * Преобладающими типами кузова являются: `sedan` (27.1%), `small` (23.8%) и `wagon` (19.4%).
# * Преобладают автомобили с механической коробкой передач (76.4%), по сравнению с автоматической коробкой передач (18.2%).
# * Наиболее популярными моделями автомобиля являются: `other` (11.5%), `golf` (8.2%) и `3er` (5.7%).
# * 67.1% автомобилей имеют пробег от 150000 км.
# * Наиболее популярные типы топлива: `petrol` (62.1%), `gasoline` (29.%) и `other` (7.1%).
# * Наиболее популярными марками автомобиля являются: `volkswagen` (21.5%), `opel` (11.1%) и `bmw` (10.6%).
# * Наибольшее количество автомобилей (72.2%) не проходили ремонт.
# * Распределение признаков с датами и почтовыми индексами практически равномерное, количество значений каждой категории незначительное.Исключим их из дальнейшего анализа.

# %% [markdown]
# Таким образом, колонки:
# * `DateCrawled`,
# * `RegistrationMonth`,
# * `DateCreated`,
# * `NumberOfPictures`,
# * `PostalCode`,
# * `LastSeen`,
#
# не представляют ценности для дальнейшего анализа и моделирования.
#
# Удалим эти колонки из датасета:

# %%
autos = autos.drop(['DateCrawled', 'RegistrationMonth', 'DateCreated', 'NumberOfPictures', 'PostalCode', 'LastSeen'], axis=1);

# %%
# Проверим количество дубликатов
print(f'Количество явных дубликатов после коррекции данных: {autos.duplicated().sum()}');
# Out:
# Количество явных дубликатов после коррекции данных: 43407

# %%
# Удалим дубликаты
autos.drop_duplicates(inplace=True);

# %% [markdown]
# ### Корреляционный анализ

# %%
# выведем корреляцию признаков
for df in datasets:
    print('Dataset:', df[1])
    corr_matrix(globals()[df[0]], globals()[df[0]].columns, df_num_columns)
    # диаграммы рассеяния
    fig = sns.PairGrid(globals()[df[0]])   
    plt.suptitle('Матрица рассеяния', y=1.01)
    fig.map_diag(sns.histplot)
    fig.map_offdiag(sns.scatterplot)
    plt.show();
# Out:
# Dataset: Данные об автомобилях

# %% [markdown]
# **Наибольшая корреляция с целевым признаком наблюдается у следующих показателей:**
# 1. `Год регистрации` автомобиля - 0.66.
# 2. `Модель` автомобиля - 0.57.
# 3. `Мощность` автомобиля - 0.45.

# %% [markdown]
# **Выявлена мультиколлинеарность между входными признаками**:
# * `Model` и `Brand` - коэффициент корреляции равен 1.
# * `Model` и `VehileType` - коэффициент корреляции равен 0.9.
#
# **С целью повышения качества моделирования, колонки с маркой и типом кузова удалим из датасета.**

# %%
autos = autos.drop(['Brand', 'VehicleType'], axis=1);

# %%
# Проверим количество дубликатов
print(f'Количество явных дубликатов после коррекции данных: {autos.duplicated().sum()}');
# Out:
# Количество явных дубликатов после коррекции данных: 9191

# %%
# Удалим дубликаты
autos.drop_duplicates(inplace=True);

# %%
# Обновим индекс датафрема
autos = autos.reset_index(drop=True)
# Проверим результат
display(autos.info());
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273991 entries, 0 to 273990
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Price             273991 non-null  int64
#  1   RegistrationYear  273991 non-null  int64
#  2   Gearbox           273991 non-null  object
#  3   Power             273991 non-null  float64
#  4   Model             273991 non-null  object
#  5   Kilometer         273991 non-null  int64
#  6   FuelType          273991 non-null  object
#  7   Repaired          273991 non-null  object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 16.7+ MB
# None

# %% [markdown]
# **После обработки пропусков, аномалий в столбцах, удаления неинформативных признаков и дубликатов в датасете осталось**

# %%
# Сохраним итоговое количество записей датасета
end_len = autos.shape[0]
print(f'{end_len} записей - {round((end_len / start_len) * 100,2)}% исходных данных.');
# Out:
# 273991 записей - 77.32% исходных данных.

# %% [markdown]
# ### Промежуточные выводы

# %% [markdown]
# **После анализа количественных признаков и исключения аномальных значений мы можем сделать следующие выводы:**
# * `Цена` варьируются от 50 до 20 000 EUR, с медианным значением в 2900 EUR. Распределение смещено влево.
# * `Год регистрации` варьируется от 1970 до 2016 г., с медианным значением 2003. Распределение смещено вправо.
# * `Мощность` варьируется от 40 до 800 л.с. с медианой в 109 л.с. Распределение смещено влево.
# * `Пробег` варьируется от 5000 до 150 000 км, с медианным значением в 150000 км. Заметно преобладание машин с большим пробегом..Распределение дискретное с небольшим количеством значений. Перенесем признак в категориальные .
# * `Месяц регистрации` - практичеси равномерное распределени, исключим его из дальнейшего анализа.
# * `Количество фотографий` - полностью отсутствуют значения. Вероятно, это связано с ошибкой при выгрузке данных. Исключим его из дальнейшего анализа.
#
# **Исходя из анализа категориальных признаков, можно отметить следующее:**
# * Преобладающими типами кузова являются: `sedan` (27.1%), `small` (23.8%) и `wagon` (19.4%).
# * Преобладают автомобили с механической коробкой передач (76.4%), по сравнению с автоматической коробкой передач (18.2%).
# * Наиболее популярными моделями автомобиля являются: `other` (11.5%), `golf` (8.2%) и `3er` (5.7%).
# * 67.1% автомобилей имеют пробег от 150000 км.
# * Наиболее популярные типы топлива: `petrol` (62.1%), `gasoline` (29.%) и `other` (7.1%).
# * Наиболее популярными марками автомобиля являются: `volkswagen` (21.5%), `opel` (11.1%) и `bmw` (10.6%).
# * Наибольшее количество автомобилей (72.2%) не проходили ремонт.
# * Распределение признаков с датами и почтовыми индексами практически равномерное, количество значений каждой категории незначительное.Исключим их из дальнейшего анализа.
#
# **Колонки:**
# * `DateCrawled`,
# * `RegistrationMonth`,
# * `DateCreated`,
# * `NumberOfPictures`,
# * `PostalCode`,
# * `LastSeen`
#
# **удалены из датасета, так как не представляют ценности для дальнейшего анализа и моделирования.**
#
# **Наибольшая корреляция с целевым признаком наблюдается у следующих показателей:**
# 1. `Год регистрации` автомобиля - 0.66.
# 2. `Модель` автомобиля - 0.57.
# 3. `Мощность` автомобиля - 0.45.
#
# **Выявлена мультиколлинеарность между входными признаками**:
# * `Model` и `Brand` - коэффициент корреляции равен 1.
# * `Model` и `VehileType` - коэффициент корреляции равен 0.9.
#
# **С целью повышения качества моделирования, колонки с маркой и типом кузова удалены из датасета.**
#
# **После обработки пропусков, аномалий в столбцах, удаления неинформативных признаков и дубликатов в датасете осталось 273991 записей - 77.32% исходных данных.**

# %% [markdown]
# ## Обучение моделей

# %% [markdown]
# ### Деление на выборки

# %%
features = autos.drop('Price', axis=1)
target = autos['Price']

features_train, features_test, target_train, target_test = train_test_split(
    features, target, test_size=0.25, random_state=RANDOM_STATE)

# Список числовых признаков
num_columns = ['RegistrationYear', 'Power']
# Список категориальных признаков
cat_columns = ['Gearbox', 'Model', 'Kilometer', 'FuelType', 'Repaired'];

# %%
# Подготовка функции создания моделей
def create_model(pipeline, param_grid, features_train, target_train):
    result = {}
    # Создание модели
    grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='neg_root_mean_squared_error')
    # Обучение модели
    start_time = time.time()
    grid_search.fit(features_train, target_train)
    result['training_time'] = round(time.time() - start_time, 2)
    # Сохраненение модели с лучшими результами
    result['best_model'] = grid_search.best_estimator_
    # Формирование предсказаний
    start_time = time.time()
    result['predictions'] = result['best_model'].predict(features_test)
    result['prediction_time'] = round(time.time() - start_time, 2)
    # Сохранение лучшей метрики
    result['rmse'] = round(grid_search.best_score_ * -1, 2)
    result['grid_search'] = grid_search
    return result

# Список моделей для тестирования
models = {
    'LinearRegression': {},
    'DecisionTreeRegressor': {},
    'LGBMRegressor': {}
};

# %% [markdown]
# ### Тестирование моделей

# %% [markdown]
# #### Линейная регрессия `LinearRegression`

# %%
# %%time
model_name = 'LinearRegression'
model = LinearRegression()
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False), cat_columns)
    ],
    remainder='passthrough' 
)
pipeline = Pipeline([
    ('preprocessor', preprocessor), 
    ('scaler', StandardScaler(with_mean=False)),
    ('regressor', model) 
])
param_grid = {
     'scaler': [StandardScaler(with_mean=False), RobustScaler(with_centering=False), None]
}
models[model_name] = create_model(pipeline, param_grid, features_train, target_train)
print(f'Модель {model_name}')
print('-' * 70)
print(f'Время обучения: {models[model_name]["training_time"]} сек.')
print(f'Время предсказания: {models[model_name]["prediction_time"]} сек.')
print(f'RMSE: {models[model_name]["rmse"]}')
# print(f'Лучшая модель:{models[model_name]["best_model"]}')
print('-' * 70);
# Out:
# Модель LinearRegression
# ----------------------------------------------------------------------
# Время обучения: 268.5 сек.
# Время предсказания: 0.45 сек.
# RMSE: 2664.71
# ----------------------------------------------------------------------
# CPU times: user 2min 58s, sys: 1min 29s, total: 4min 28s
# Wall time: 4min 28s

# %% [markdown]
# #### Дерево решений `DecisionTreeRegressor`

# %%
# %%time
model_name = 'DecisionTreeRegressor'
model = DecisionTreeRegressor(random_state=RANDOM_STATE)
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False), cat_columns)
    ],
    remainder='passthrough' 
)
pipeline = Pipeline([
    ('preprocessor', preprocessor), 
    ('scaler', StandardScaler(with_mean=False)),
    ('regressor', model) 
])
param_grid = {
    'scaler': [StandardScaler(with_mean=False), RobustScaler(with_centering=False), None],
    'regressor__max_depth': [5, 10, 15]
}
models[model_name] = create_model(pipeline, param_grid, features_train, target_train)
print(f'Модель {model_name}')
print('-' * 70)
print(f'Время обучения: {models[model_name]["training_time"]} сек.')
print(f'Время предсказания: {models[model_name]["prediction_time"]} сек.')
print(f'RMSE: {models[model_name]["rmse"]}')
# print(f'Лучшая модель:{models[model_name]["best_model"]}')
print('-' * 70);
# Out:
# Модель DecisionTreeRegressor
# ----------------------------------------------------------------------
# Время обучения: 206.92 сек.
# Время предсказания: 0.53 сек.
# RMSE: 2045.43
# ----------------------------------------------------------------------
# CPU times: user 2min 56s, sys: 30.8 s, total: 3min 27s
# Wall time: 3min 27s

# %% [markdown]
# #### Градиентный бустинг `LGBMRegressor`

# %%
# %%time
model_name = 'LGBMRegressor'
model = LGBMRegressor(random_state=RANDOM_STATE)
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False), cat_columns)
    ],
    remainder='passthrough'
)
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('scaler', StandardScaler(with_mean=False)),
    ('regressor', model)
])
param_grid = {
    'scaler': [StandardScaler(with_mean=False), None],
    'regressor__num_leaves': [50, 100] 
}
models[model_name] = create_model(pipeline, param_grid, features_train, target_train)
print(f'Модель {model_name}')
print('-' * 70)
print(f'Время обучения: {models[model_name]["training_time"]} сек.')
print(f'Время предсказания: {models[model_name]["prediction_time"]} сек.')
print(f'RMSE: {models[model_name]["rmse"]}')
# print(f'Лучшая модель:{models[model_name]["best_model"]}')
print('-' * 70);
# Out:
# Модель LGBMRegressor
# ----------------------------------------------------------------------
# Время обучения: 731.34 сек.
# Время предсказания: 1.49 сек.
# RMSE: 1761.43
# ----------------------------------------------------------------------
# CPU times: user 11min 46s, sys: 20 s, total: 12min 5s
# Wall time: 12min 12s

# %% [markdown]
# ## Анализ моделей

# %% [markdown]
# ### Сравнение моделей

# %%
# Cформируем таблицу с результати
columns=['model', 'rmse', 'training_time', 'prediction_time']
keys = list(models.keys())
data = []
for key in models.keys():
    data.append([
            key,
            models[key]['rmse'],
            models[key]['training_time'], 
            models[key]['prediction_time']
       ])
results_df = pd.DataFrame(data=data, columns=columns).sort_values(by=['rmse']);

# %%
# Покажем таблицу с результати обучения и предсказаниями модели 
display(results_df);
# Out:
#                    model     rmse  training_time  prediction_time
# 2          LGBMRegressor  1761.43         731.34             1.49
# 1  DecisionTreeRegressor  2045.43         206.92             0.53
# 0       LinearRegression  2664.71         268.50             0.45

# %%
# Покажем диаграмму сравнения моделей по времени обучения
show_barplot(
    'Сравнение моделей по времени обучения',
    results_df['model'],
    results_df['training_time'],
    '',
    'Время обучения, сек.'
)
# Покажем диаграмму сравнения моделей по времени предсказания
show_barplot(
    'Сравнение моделей по времени предсказания',
    results_df['model'],
    results_df['prediction_time'],
    '',
    'Время предсказания, сек.'
)
# Покажем диаграмму сравнения моделей по RMSE
ax = sns.barplot(x=results_df['model'], y=results_df['rmse']) 
plt.suptitle('Сравнение моделей по RMSE', fontsize=16, ha='center')
ax.set_xlabel('')
ax.set_ylabel('Значение RMSE')
# добавим линию "отсечки" с целевым RMSE 2500
ax.axhline(y = 2500, color = 'red', label = 'заданный уровень RMSE', linestyle='dashed')
plt.legend()
ax.bar_label(ax.containers[0],
             color='black',
             fontsize=12,
             fontweight='bold')
plt.show();

# %% [markdown]
# **Результаты сравнения моделей:**
# * Лучшей моделью по метрике RMSE является `LGBMRegressor`.
# * Лvлучшей моделью по времени предсказания является `LinearRegressor`.
# * Лvлучшей моделью по времени обучения является `DecisionTreeRegressor`.
#
# 1. Так как, для заказчика первично качество предсказания модели, то в качестве лучшей модели выберем `LGBMRegressor`, которая имеет существенно лучшее значение RMSE, несмотря на более длительное время обучения и предсказания.
# 2. На втором месте модель `DecisionTreeRegressor`, которая имеет удовлетворяющее заказчика качество предсказания на уровне < 2500 и хорошее время обучения и предсказания.
# 3. Модель `LinearRegressor` не удовлетворяет заказчика по качеству предсказания.

# %% [markdown]
# ### Проверка лучшей модели на тестовых данных

# %%
# %%time
start_time = time.time()
predictions_test = models['LGBMRegressor']['best_model'].predict(features_test)
predictions_test_time = round(time.time() - start_time, 2)
rmse_test = round(mean_squared_error(target_test, predictions_test, squared=False), 2)
print(f'Время предсказания на тестовой выборке: {predictions_test_time} сек.')
print(f'RMSE на тестовой выборке: {rmse_test}')
print('-' * 70);
# Out:
# Время предсказания на тестовой выборке: 1.47 сек.
# RMSE на тестовой выборке: 1751.32
# ----------------------------------------------------------------------
# CPU times: user 1.32 s, sys: 216 ms, total: 1.54 s
# Wall time: 1.48 s

# %% [markdown]
# ### Анализ важности признаков

# %%
# %%time
# Подготовим данныe
pipeline_final = models['LGBMRegressor']['grid_search'].estimator
features_train_new = pipeline_final.named_steps['preprocessor'].fit_transform(features_train)
features_test_new = pipeline_final.named_steps['preprocessor'].transform(features_test)
feature_names = pipeline_final.named_steps['preprocessor'].get_feature_names_out()
data_new = pd.DataFrame(features_test_new, columns=feature_names)
model = models['LGBMRegressor']['best_model'].named_steps['regressor']


# shap_test = shap.TreeExplainer(model).shap_values(data_new)
# shap.summary_plot(shap_test, data_new, max_display=25, auto_size_plot=True)


explainer = shap.TreeExplainer(model, features_train_new)
shap_values = explainer(data_new)


# Построим графики
shap.plots.bar(shap_values, max_display=25)
shap.plots.beeswarm(shap_values)
print('-' * 70);
# Out:
# 100%|===================| 68417/68498 [03:28<00:00]
# ----------------------------------------------------------------------
# CPU times: user 3min 33s, sys: 1.12 s, total: 3min 34s
# Wall time: 3min 35s

# %% [markdown]
# ### Промежуточные выводы

# %% [markdown]
# **В ходе обучения, оценки и тестирования моделей:**
#
# **Обучены три модели:**
# * `LinearRegression` - линейная регрессия,
# * `DecisionTreeRegressor` - дерево решений,
# * `LGBMRegressor` - градиентный бустинг.
#
# **Результаты сравнения моделей:**
# * Лучшей моделью по метрике RMSE является `LGBMRegressor`.
# * Лvлучшей моделью по времени предсказания является `LinearRegressor`.
# * Лvлучшей моделью по времени обучения является `DecisionTreeRegressor`.
#
# 1. Так как, для заказчика первично качество предсказания модели, то в качестве лучшей модели выберем `LGBMRegressor`, которая имеет существенно лучшее значение RMSE, несмотря на более длительное время обучения и предсказания.
# 2. На втором месте модель `DecisionTreeRegressor`, которая имеет удовлетворяющее заказчика качество предсказания на уровне < 2500 и хорошее время обучения и предсказания.
# 3. Модель `LinearRegressor` не удовлетворяет заказчика по качеству предсказания.
#
# **Выводы:**
# 1. Так как, для заказчика первично качество предсказания модели, то в качестве лучшей модели выберем `LGBMRegressor`, которая имеет существенно лучшее значение RMSE, несмотря на более длительное время обучения и предсказания.
# 2. На втором месте модель `DecisionTreeRegressor`, которая имеет удовлетворяющее заказчика качество предсказания на уровне ниже 2500 и хорошее время обучения и предсказания.
# 3. Модель `LinearRegressor` не удовлетворяет заказчика по качеству предсказания.
#
# **Проведена проверка лучшей модели на тестовых данных. Значение RMSE на тествой выборке практически равно значению на тренировочной выборке.**
#
# **Проведена оценка важности признаков лучшей модели. Наиболее важными для модели признаками являются:**
# * `Repaired`,
# * `Kilometer`,
# * `Gearbox`.

# %% [markdown]
# ## Итоговые выводы

# %% [markdown]
# ### Отчет о проделанной работе

# %% [markdown]
# **Цель данного проекта - построить модель для определения рыночной стоимости автомобилей.**
#
# **В ходе загрузки и изучения данных выявили, что:**
# - Выявлены явные дубликаты.
# - Выявлены пропуски в данных.
#
# **В ходе предобработки данных:**
# - Устранены явные дубликаты.
# - Устранены пропуски в данных.
#
# **После анализа количественных признаков и исключения аномальных значений мы можем сделать следующие выводы:**
# * `Цена` варьируются от 50 до 20 000 EUR, с медианным значением в 2900 EUR. Распределение смещено влево.
# * `Год регистрации` варьируется от 1970 до 2016 г., с медианным значением 2003. Распределение смещено вправо.
# * `Мощность` варьируется от 40 до 800 л.с. с медианой в 109 л.с. Распределение смещено влево.
# * `Пробег` варьируется от 5000 до 150 000 км, с медианным значением в 150000 км. Заметно преобладание машин с большим пробегом..Распределение дискретное с небольшим количеством значений. Перенесем признак в категориальные .
# * `Месяц регистрации` - практичеси равномерное распределени, исключим его из дальнейшего анализа.
# * `Количество фотографий` - полностью отсутствуют значения. Вероятно, это связано с ошибкой при выгрузке данных. Исключим его из дальнейшего анализа.
#
# **Исходя из анализа категориальных признаков, можно отметить следующее:**
# * Преобладающими типами кузова являются: `sedan` (27.1%), `small` (23.8%) и `wagon` (19.4%).
# * Преобладают автомобили с механической коробкой передач (76.4%), по сравнению с автоматической коробкой передач (18.2%).
# * Наиболее популярными моделями автомобиля являются: `other` (11.5%), `golf` (8.2%) и `3er` (5.7%).
# * 67.1% автомобилей имеют пробег от 150000 км.
# * Наиболее популярные типы топлива: `petrol` (62.1%), `gasoline` (29.%) и `other` (7.1%).
# * Наиболее популярными марками автомобиля являются: `volkswagen` (21.5%), `opel` (11.1%) и `bmw` (10.6%).
# * Наибольшее количество автомобилей (72.2%) не проходили ремонт.
# * Распределение признаков с датами и почтовыми индексами практически равномерное, количество значений каждой категории незначительное.Исключим их из дальнейшего анализа.
#
# **Колонки:**
# * `DateCrawled`,
# * `RegistrationMonth`,
# * `DateCreated`,
# * `NumberOfPictures`,
# * `PostalCode`,
# * `LastSeen`
#
# **удалены из датасета, так как не представляют ценности для дальнейшего анализа и моделирования.**
#
# **Наибольшая корреляция с целевым признаком наблюдается у следующих показателей:**
# 1. `Год регистрации` автомобиля - 0.66.
# 2. `Модель` автомобиля - 0.57.
# 3. `Мощность` автомобиля - 0.45.
#
# **Выявлена мультиколлинеарность между входными признаками**:
# * `Model` и `Brand` - коэффициент корреляции равен 1.
# * `Model` и `VehileType` - коэффициент корреляции равен 0.9.
#
# **С целью повышения качества моделирования, колонки с маркой и типом кузова удалены из датасета.**
#
# **После обработки пропусков, аномалий в столбцах, удаления неинформативных признаков и дубликатов в датасете осталось 273991 записей - 77.32% исходных данных.**
#
# **В ходе обучения, оценки и тестирования моделей:**
#
# **Обучены три модели:**
# * `LinearRegression` - линейная регрессия,
# * `DecisionTreeRegressor` - дерево решений,
# * `LGBMRegressor` - градиентный бустинг.
#
# **Результаты сравнения моделей:**
# * Лучшей моделью по метрике RMSE является `LGBMRegressor`.
# * Лvлучшей моделью по времени предсказания является `LinearRegressor`.
# * Лvлучшей моделью по времени обучения является `DecisionTreeRegressor`.
#
# 1. Так как, для заказчика первично качество предсказания модели, то в качестве лучшей модели выберем `LGBMRegressor`, которая имеет существенно лучшее значение RMSE, несмотря на более длительное время обучения и предсказания.
# 2. На втором месте модель `DecisionTreeRegressor`, которая имеет удовлетворяющее заказчика качество предсказания на уровне < 2500 и хорошее время обучения и предсказания.
# 3. Модель `LinearRegressor` не удовлетворяет заказчика по качеству предсказания.
#
# **Выводы:**
# 1. Так как, для заказчика первично качество предсказания модели, то в качестве лучшей модели выберем `LGBMRegressor`, которая имеет существенно лучшее значение RMSE, несмотря на более длительное время обучения и предсказания.
# 2. На втором месте модель `DecisionTreeRegressor`, которая имеет удовлетворяющее заказчика качество предсказания на уровне ниже 2500 и хорошее время обучения и предсказания.
# 3. Модель `LinearRegressor` не удовлетворяет заказчика по качеству предсказания.
#
# **Проведена проверка лучшей модели на тестовых данных. Значение RMSE на тествой выборке практически равно значению на тренировочной выборке.**
#
# **Проведена оценка важности признаков лучшей модели. Наиболее важными для модели признаками являются:**
# * `Repaired`,
# * `Kilometer`,
# * `Gearbox`.

# %% [markdown]
# ### Выводы

# %% [markdown]
# 1. **По результатам оценки определено, что наилучшие показатели продемонстрировала модель `LGBMRegressor`.**
#
# 2. **Модель сохранена в переменной `models['LGBMRegressor']['best_model']`**.
#
# 3. **Модель рекомендована заказчику для определения рыночной стоимости автомобилей.**
